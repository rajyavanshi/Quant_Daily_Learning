# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600&family=Crimson+Text:ital,wght@0,400;0,600;1,400&display=swap" rel="stylesheet">
#
# <div style="font-family: 'Inter', -apple-system, sans-serif; color: #1a202c; line-height: 1.6; max-width: 900px; margin: auto; background-color: #ffffff; padding: 25px; border: 1px solid #e2e8f0; border-radius: 8px;">
#
# <div style="text-align: center; padding-bottom: 20px; border-bottom: 2px solid #1a202c; margin-bottom: 30px;">
# <span style="color: #718096; font-size: 12px; text-transform: uppercase; letter-spacing: 2px; font-weight: bold;">
# Quantitative Research Series • Vol. 01
# </span>
#
# <h1 style="font-family: 'Crimson Text', serif; font-style: italic; font-weight: 500; color: #1a202c; font-size: 32px; margin: 10px 0;">
# Module 1: Financial Asset Structuring & OHLCV Analysis
# </h1>
# </div>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 1. What is a Financial Asset?
# </h3>
#
# <p>
# A financial asset is a tradable instrument that represents ownership, contractual claims on future cash flows, or exposure to market price movements.
# Financial assets are traded on organized exchanges or over-the-counter markets and form the fundamental building blocks of global capital markets.
# </p>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin: 20px 0;">
#
# <div style="background: #f8fafc; padding: 15px; border-radius: 6px; border: 1px solid #edf2f7;">
# <strong>Stocks & Equity</strong><br>
# <span style="font-size: 14px;">
# Ownership shares in a corporation. Investors may earn capital gains and dividends.
# Example: Apple (AAPL), Tesla (TSLA).
# </span>
# </div>
#
# <div style="background: #f8fafc; padding: 15px; border-radius: 6px; border: 1px solid #edf2f7;">
# <strong>Indices & ETFs</strong><br>
# <span style="font-size: 14px;">
# Indices measure the performance of a basket of assets (S&P 500, NASDAQ).
# ETFs allow investors to trade those indices like individual securities.
# </span>
# </div>
#
# </div>
#
# <p>
# Other important categories include commodities, currencies, derivatives, and cryptocurrencies.
# In quantitative finance, each asset is modeled as a <strong>stochastic price process evolving through time</strong>.
# </p>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px; margin-top: 30px;">
# 2. Financial Market Data
# </h3>
#
# <p>
# Market data is the structured record of how assets trade over time.
# For quantitative analysis, this data is organized as a <strong>time series</strong>, meaning each observation corresponds to a specific point in time.
# </p>
#
# <p>
# A time series dataset contains sequential observations:
# </p>
#
# <table style="width:100%; border-collapse: collapse; margin: 15px 0; font-size: 14px; border:1px solid #e2e8f0;">
# <tr style="background-color:#2d3748; color:white;">
# <th style="padding:10px;">Date</th>
# <th style="padding:10px;">Open</th>
# <th style="padding:10px;">High</th>
# <th style="padding:10px;">Low</th>
# <th style="padding:10px;">Close</th>
# <th style="padding:10px;">Volume</th>
# </tr>
#
# <tr>
# <td style="padding:8px;">2024-01-01</td>
# <td style="padding:8px;">150</td>
# <td style="padding:8px;">155</td>
# <td style="padding:8px;">149</td>
# <td style="padding:8px;">153</td>
# <td style="padding:8px;">2.1M</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">2024-01-02</td>
# <td style="padding:8px;">153</td>
# <td style="padding:8px;">156</td>
# <td style="padding:8px;">151</td>
# <td style="padding:8px;">155</td>
# <td style="padding:8px;">1.8M</td>
# </tr>
#
# </table>
#
# <p>
# Each row represents the state of the market during a specific time interval.
# </p>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 3. OHLCV Data Structure
# </h3>
#
# <p>
# Financial price data is stored in the standard <strong>OHLCV format</strong>.
# These values summarize the trading activity during a time interval.
# </p>
#
# <table style="width:100%; border-collapse: collapse; margin: 15px 0; font-size: 14px; border:1px solid #e2e8f0;">
# <tr style="background-color:#2d3748; color:white;">
# <th style="padding:10px;">Field</th>
# <th style="padding:10px;">Definition</th>
# </tr>
#
# <tr>
# <td style="padding:8px;">Open</td>
# <td style="padding:8px;">First traded price of the period</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">High</td>
# <td style="padding:8px;">Maximum price reached</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">Low</td>
# <td style="padding:8px;">Minimum price reached</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">Close</td>
# <td style="padding:8px;">Final traded price of the interval</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">Volume</td>
# <td style="padding:8px;">Number of shares or contracts traded</td>
# </tr>
#
# </table>
#
# <p>
# OHLCV data can exist at different time resolutions:
# </p>
#
# <ul>
# <li>Daily data</li>
# <li>Hourly data</li>
# <li>Minute data</li>
# <li>Tick-level data (every trade)</li>
# </ul>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 4. Adjusted Close Price
# </h3>
#
# <p>
# Raw closing prices do not always reflect the true economic value of an asset because of corporate actions.
# </p>
#
# <ul>
# <li><strong>Stock Splits</strong> – change the price but not investor wealth</li>
# <li><strong>Dividends</strong> – reduce the stock price when paid</li>
# </ul>
#
# <p>
# To correct these distortions, financial datasets include the column <strong>Adjusted Close</strong>.
# </p>
#
# <p>
# Quantitative calculations such as returns, volatility, and portfolio optimization should always use:
# </p>
#
# <p style="font-weight:bold;">
# Adjusted Close
# </p>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 5. Mathematical Representation of Price
# </h3>
#
# <p>
# In quantitative finance, asset prices are modeled as stochastic processes.
# Let:
# </p>
#
# <p>
# P<sub>t</sub> = price of an asset at time t
# </p>
#
# <p>
# The sequence
# </p>
#
# <p>
# P₁, P₂, P₃, ... , Pₜ
# </p>
#
# <p>
# forms a discrete-time stochastic process describing the evolution of the market.
# </p>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 6. Log Returns
# </h3>
#
# <p>
# Instead of analyzing raw prices, quantitative models typically analyze <strong>returns</strong>.
# </p>
#
# <p>
# The logarithmic return is defined as:
# </p>
#
# <p style="font-weight:bold;">
# r<sub>t</sub> = log(P<sub>t</sub> / P<sub>t-1</sub>)
# </p>
#
# <p>
# Log returns are preferred because they:
# </p>
#
# <ul>
# <li>are additive through time</li>
# <li>simplify mathematical modeling</li>
# <li>are compatible with continuous-time finance models</li>
# </ul>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 7. Time Indexing
# </h3>
#
# <p>
# Financial time series are indexed by trading time rather than calendar time.
# </p>
#
# <p>
# This means that weekends and holidays appear as gaps in the dataset.
# These gaps are normal and do not indicate missing data.
# </p>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 8. Importance for Quantitative Research
# </h3>
#
# <p>
# Understanding the structure of financial data is the first step in building quantitative models.
# </p>
#
# <p>
# Once the dataset is properly structured, researchers can analyze:
# </p>
#
# <ul>
# <li>return distributions</li>
# <li>volatility clustering</li>
# <li>trend behavior</li>
# <li>market microstructure</li>
# <li>statistical arbitrage opportunities</li>
# </ul>
#
# <p style="margin-top:25px; font-weight:bold;">
# Next Step: Computing Log Returns and Moving Averages.
# </p>
#
# </div>

# %%
import pandas as pd
import yfinance as yf

def get_stock_data(ticker, start_date, end_date):
    """
    Fetch historical stock data for a given ticker symbol and date range.

    Parameters:
    ticker (str): The stock ticker symbol (e.g., 'AAPL' for Apple Inc.).
    start_date (str): The start date for the data in 'YYYY-MM-DD' format.
    end_date (str): The end date for the data in 'YYYY-MM-DD' format.

    Returns:
    pd.DataFrame: A DataFrame containing the historical stock data.
    """
    try:
        # Fetch the stock data using yfinance
        stock_data = yf.download(ticker, start=start_date, end=end_date)
        return stock_data
    except Exception as e:
        print(f"An error occurred while fetching stock data: {e}")
        return pd.DataFrame()
if __name__ == "__main__":
    # Example usage
    ticker = "AAPL"
    
    start_date = "2020-01-01"
    end_date = "2021-01-01"
    
    data = get_stock_data(ticker, start_date, end_date)
    display(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.400520  72.460784  71.156682  71.409785  135480400
# 2020-01-03  71.696625  72.455943  71.472447  71.629130  146322800
# 2020-01-06  72.267960  72.306529  70.568532  70.819231  118387200
# 2020-01-07  71.928047  72.533087  71.708687  72.277571  108872000
# 2020-01-08  73.085098  73.386416  71.631544  71.631544  132079200

# %%
# using the function to fetch multiple stocks data from nseindia.com
# starting : january 1, 2026
# endimg : current date and time

"""Note: The tickers used in the example are from the National Stock Exchange of India (NSE).
Make sure to have the yfinance library installed and an active internet connection to fetch the data."""

""" Tickers used in the example:
1. ADANIPORTS.NS - Adani Ports and Special Economic Zone Limited
2. RELINFRA.NS - Reliance Infrastructure Limited
3. MON100.NS - Monnet Ispat and Energy Limited
4. IOC.NS - Indian Oil Corporation Limited
5. ONGC.NS - Oil and Natural Gas Corporation Limited
6. IDEA.NS - Vodafone Idea Limited
7. GOLDBEES.NS - Nippon India Gold BeES
8. MAFANG.NS - MA Financial Services Limited
"""

tickers = ["ADANIPORTS.NS", "RELINFRA.NS","MON100.NS","IOC.NS","ONGC.NS","IDEA.NS","GOLDBEES.NS","MAFANG.NS","PULSRIN.BO"]
for ticker in tickers:
    data = get_stock_data(ticker, "2026-01-01", pd.Timestamp.now().strftime("%Y-%m-%d"))
    print(f"Data for {ticker}:")
    display(data.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data for ADANIPORTS.NS:
# Price              Close          High           Low          Open  \
# Ticker     ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS
# Date
# 2026-03-09   1421.300049   1436.099976   1405.000000   1405.000000
# 2026-03-10   1424.099976   1470.300049   1416.500000   1450.000000
# 2026-03-11   1410.800049   1454.900024   1405.699951   1425.000000
# 2026-03-12   1391.500000   1418.599976   1375.300049   1402.500000
# 2026-03-13   1363.199951   1390.000000   1354.000000   1388.699951
#
# Price             Volume
# Ticker     ADANIPORTS.NS
# Date
# 2026-03-09       4874245
# 2026-03-10       2706284
# 2026-03-11       2212011
# 2026-03-12       2699173
# 2026-03-13       2688551
# [*********************100%***********************]  1 of 1 completed
# Data for RELINFRA.NS:
# Price            Close        High         Low        Open      Volume
# ...

# %%
data = get_stock_data("ADANIPORTS.NS", "2026-01-01", pd.Timestamp.now().strftime("%Y-%m-%d"))
print("Data for ADANIPORTS.NS:")
display(data.tail())
print("Columns in the DataFrame:")
print(data.columns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data for ADANIPORTS.NS:
# Price              Close          High           Low          Open  \
# Ticker     ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS
# Date
# 2026-03-09   1421.300049   1436.099976   1405.000000   1405.000000
# 2026-03-10   1424.099976   1470.300049   1416.500000   1450.000000
# 2026-03-11   1410.800049   1454.900024   1405.699951   1425.000000
# 2026-03-12   1391.500000   1418.599976   1375.300049   1402.500000
# 2026-03-13   1363.199951   1390.000000   1354.000000   1388.699951
#
# Price             Volume
# Ticker     ADANIPORTS.NS
# Date
# 2026-03-09       4874245
# 2026-03-10       2706284
# 2026-03-11       2212011
# 2026-03-12       2699173
# 2026-03-13       2688551
# Columns in the DataFrame:
# MultiIndex([( 'Close', 'ADANIPORTS.NS'),
#             (  'High', 'ADANIPORTS.NS'),
#             (   'Low', 'ADANIPORTS.NS'),
#             (  'Open', 'ADANIPORTS.NS'),
# ...

# %%
# basic data exploration
print("Data types of each column:")
print(data.dtypes)
print("\nSummary statistics for numerical columns:")
print(data.describe())
print("\nNumber of missing values in each column:")
print(data.isnull().sum())
# Out:
# Data types of each column:
# Price   Ticker
# Close   ADANIPORTS.NS    float64
# High    ADANIPORTS.NS    float64
# Low     ADANIPORTS.NS    float64
# Open    ADANIPORTS.NS    float64
# Volume  ADANIPORTS.NS      int64
# dtype: object
#
# Summary statistics for numerical columns:
# Price          Close          High           Low          Open        Volume
# Ticker ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS ADANIPORTS.NS
# count      50.000000     50.000000     50.000000     50.000000  5.000000e+01
# mean     1471.070002   1489.364006   1451.155994   1472.187998  2.513625e+06
# std        68.641243     64.492236     68.205379     66.499921  1.912846e+06
# min      1308.400024   1368.300049   1292.000000   1334.300049  0.000000e+00
# 25%      1420.175049   1431.524994   1405.174988   1422.000000  1.359715e+06
# 50%      1471.750000   1491.950012   1459.650024   1470.400024  2.049440e+06
# 75%      1537.774994   1550.950012   1510.225037   1540.974976  3.069867e+06
# ...

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600&family=Crimson+Text:ital,wght@0,400;0,600;1,400&display=swap" rel="stylesheet">
#
# <div style="font-family: 'Inter', -apple-system, sans-serif; color: #1a202c; line-height: 1.6; max-width: 900px; margin: auto; background-color: #ffffff; padding: 25px; border: 1px solid #e2e8f0; border-radius: 8px;">
#
# <div style="text-align: center; padding-bottom: 20px; border-bottom: 2px solid #1a202c; margin-bottom: 30px;">
# <span style="color: #718096; font-size: 12px; text-transform: uppercase; letter-spacing: 2px; font-weight: bold;">
# Quantitative Research Series • Vol. 02
# </span>
#
# <h1 style="font-family: 'Crimson Text', serif; font-style: italic; font-weight: 500; color: #1a202c; font-size: 32px; margin: 10px 0;">
# Module 2: Statistical Diagnostics : Understanding `.describe()`
# </h1>
# <!-- <h1 style="font-family: 'Crimson Text', serif; font-style: italic; font-weight: 500; color: #1a202c; font-size: 32px; margin: 10px 0;">
# Statistical Diagnostics with Pandas: Understanding `.describe()`
# </h1> -->
# </div>
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 1. Purpose of `.describe()`
# </h3>
#
# <p>
# The <strong>.describe()</strong> function in Pandas provides a concise statistical summary of numerical variables within a dataset.
# It is one of the first exploratory tools used in data analysis to understand the general structure of the data before building statistical or machine learning models.
# </p>
#
# <p>
# For financial datasets, `.describe()` helps analysts quickly inspect important characteristics such as:
# </p>
#
# <ul>
# <li>average return of an asset</li>
# <li>volatility of the time series</li>
# <li>presence of extreme observations</li>
# <li>distribution symmetry or skewness</li>
# <li>data completeness</li>
# </ul>
#
# <p>
# Because financial markets generate massive amounts of time-series data, summary statistics act as a <strong>first diagnostic snapshot of market behavior</strong>.
# </p>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 2. Statistical Metrics Returned
# </h3>
#
# <p>
# For numerical variables, `.describe()` returns the following summary statistics:
# </p>
#
# <table style="width:100%; border-collapse: collapse; margin: 15px 0; font-size: 14px; border:1px solid #e2e8f0;">
#
# <tr style="background-color:#2d3748; color:white;">
# <th style="padding:10px;">Statistic</th>
# <th style="padding:10px;">Meaning</th>
# <th style="padding:10px;">Financial Interpretation</th>
# </tr>
#
# <tr>
# <td style="padding:8px;">count</td>
# <td style="padding:8px;">Number of non-missing observations</td>
# <td style="padding:8px;">Number of trading observations available</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">mean</td>
# <td style="padding:8px;">Arithmetic average</td>
# <td style="padding:8px;">Average return of the asset</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">std</td>
# <td style="padding:8px;">Standard deviation</td>
# <td style="padding:8px;">Volatility of the asset</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">min</td>
# <td style="padding:8px;">Smallest observed value</td>
# <td style="padding:8px;">Worst observed loss</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">25%</td>
# <td style="padding:8px;">First quartile</td>
# <td style="padding:8px;">Lower bound of typical returns</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">50%</td>
# <td style="padding:8px;">Median</td>
# <td style="padding:8px;">Typical central return</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">75%</td>
# <td style="padding:8px;">Third quartile</td>
# <td style="padding:8px;">Upper bound of typical returns</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">max</td>
# <td style="padding:8px;">Largest observed value</td>
# <td style="padding:8px;">Largest observed gain</td>
# </tr>
#
# </table>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 3. Example Interpretation for Financial Returns
# </h3>
#
# <p>
# Consider the following output of `.describe()` applied to daily stock returns.
# </p>
#
# <table style="width:100%; border-collapse: collapse; margin: 15px 0; font-size: 14px; border:1px solid #e2e8f0;">
#
# <tr style="background-color:#2d3748; color:white;">
# <th style="padding:10px;">Statistic</th>
# <th style="padding:10px;">Value</th>
# </tr>
#
# <tr>
# <td style="padding:8px;">count</td>
# <td style="padding:8px;">252</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">mean</td>
# <td style="padding:8px;">0.0012</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">std</td>
# <td style="padding:8px;">0.018</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">min</td>
# <td style="padding:8px;">-0.082</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">25%</td>
# <td style="padding:8px;">-0.006</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">50%</td>
# <td style="padding:8px;">0.0004</td>
# </tr>
#
# <tr>
# <td style="padding:8px;">75%</td>
# <td style="padding:8px;">0.009</td>
# </tr>
#
# <tr style="background:#f7fafc;">
# <td style="padding:8px;">max</td>
# <td style="padding:8px;">0.065</td>
# </tr>
#
# </table>
#
# <p>
# From this table an analyst can infer:
# </p>
#
# <ul>
# <li>Average daily return ≈ <strong>0.12%</strong></li>
# <li>Volatility ≈ <strong>1.8%</strong></li>
# <li>Worst trading day ≈ <strong>-8.2%</strong></li>
# <li>Best trading day ≈ <strong>+6.5%</strong></li>
# </ul>
#
# <p>
# This quick diagnostic helps evaluate whether a dataset behaves like a typical financial return series.
# </p>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 4. Mathematical Interpretation
# </h3>
#
# <p>
# Let a dataset contain observations:
# </p>
#
# <p>
# x₁, x₂, x₃, … , xₙ
# </p>
#
# <p>
# The mean is defined as:
# </p>
#
# <p style="font-weight:bold;">
# μ = (1/n) Σ xᵢ
# </p>
#
# <p>
# The standard deviation measures dispersion around the mean:
# </p>
#
# <p style="font-weight:bold;">
# σ = √((1/(n−1)) Σ (xᵢ − μ)²)
# </p>
#
# <p>
# Quartiles divide the ordered dataset into four equal segments.
# </p>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 5. Interquartile Range and Outliers
# </h3>
#
# <p>
# The interquartile range is defined as:
# </p>
#
# <p style="font-weight:bold;">
# IQR = Q3 − Q1
# </p>
#
# <p>
# Outliers are often defined as values outside:
# </p>
#
# <p style="font-weight:bold;">
# [ Q1 − 1.5 × IQR , Q3 + 1.5 × IQR ]
# </p>
#
# <p>
# In finance, extreme outliers often correspond to:
# </p>
#
# <ul>
# <li>earnings announcements</li>
# <li>macroeconomic shocks</li>
# <li>market crashes</li>
# <li>short squeezes</li>
# </ul>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 6. Interpreting `.describe()` in Practice
# </h3>
#
# <p>
# Professional analysts can extract multiple insights instantly from the summary table.
# </p>
#
# <ul>
# <li><strong>Missing Data:</strong> Compare dataset size with the count value.</li>
# <li><strong>Skewness:</strong> Compare mean and median.</li>
# <li><strong>Outliers:</strong> Observe the gap between max and the upper quartile.</li>
# <li><strong>Volatility:</strong> Assess the magnitude of the standard deviation.</li>
# <li><strong>Scale:</strong> Check whether values are realistic.</li>
# </ul>
#
# <p>
# For example, if:
# </p>
#
# <pre>
# mean = 0.001
# std = 0.03
# </pre>
#
# <p>
# The volatility is <strong>30 times larger than the mean</strong>, indicating a highly volatile asset.
# </p>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 7. Limitations of `.describe()`
# </h3>
#
# <p>
# Although useful, `.describe()` provides only <strong>univariate statistics</strong>.
# It does not reveal:
# </p>
#
# <ul>
# <li>relationships between variables</li>
# <li>multimodal distributions</li>
# <li>volatility clustering</li>
# <li>temporal dependencies</li>
# </ul>
#
# <p>
# Two datasets can share identical summary statistics while having completely different distributions.
# </p>
#
# ---
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 8. Typical Data Analysis Workflow
# </h3>
#
# <p>
# In practice, analysts often follow this exploratory workflow:
# </p>
#
# <pre>
# df.head()
# df.info()
# df.describe()
# df.isna().sum()
# df.hist()
# df.corr()
# </pre>
#
# <p>
# This sequence helps construct a complete statistical understanding of the dataset before performing advanced modeling or quantitative research.
# </p>
#
# <p style="margin-top:25px; font-weight:bold;">
# Next Step: Distribution Analysis, Log Returns, and Volatility Modeling.
# </p>
#
# </div>

# %%
import pandas as pd
import numpy as np

def data_diagnostic(df):

    report = pd.DataFrame()

    report["dtype"] = df.dtypes
    report["count"] = df.count()
    report["missing"] = df.isna().sum()
    report["missing_%"] = (df.isna().sum() / len(df)) * 100

    report["mean"] = df.mean(numeric_only=True)
    report["std"] = df.std(numeric_only=True)
    report["min"] = df.min(numeric_only=True)
    report["25%"] = df.quantile(0.25, numeric_only=True)
    report["median"] = df.median(numeric_only=True)
    report["75%"] = df.quantile(0.75, numeric_only=True)
    report["max"] = df.max(numeric_only=True)

    report["skew"] = df.skew(numeric_only=True)
    report["kurtosis"] = df.kurtosis(numeric_only=True)

    return report

data_diagnostic(data)
# Out:
#                         dtype  count  missing  missing_%          mean  \
# Price  Ticker
# Close  ADANIPORTS.NS  float64     50        0        0.0  1.471070e+03
# High   ADANIPORTS.NS  float64     50        0        0.0  1.489364e+03
# Low    ADANIPORTS.NS  float64     50        0        0.0  1.451156e+03
# Open   ADANIPORTS.NS  float64     50        0        0.0  1.472188e+03
# Volume ADANIPORTS.NS    int64     50        0        0.0  2.513625e+06
#
#                                std          min           25%        median  \
# Price  Ticker
# Close  ADANIPORTS.NS  6.864124e+01  1308.400024  1.420175e+03  1.471750e+03
# High   ADANIPORTS.NS  6.449224e+01  1368.300049  1.431525e+03  1.491950e+03
# Low    ADANIPORTS.NS  6.820538e+01  1292.000000  1.405175e+03  1.459650e+03
# Open   ADANIPORTS.NS  6.649992e+01  1334.300049  1.422000e+03  1.470400e+03
# Volume ADANIPORTS.NS  1.912846e+06     0.000000  1.359715e+06  2.049440e+06
#
# ...

# %%
# Visualization of the stock data
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
plt.figure(figsize=(14, 7))
# print(data.columns)-> multiindex format 
sns.lineplot(data=data, x=data.index, y=data["Close"].squeeze()) 
plt.title("Closing Price of ADANIPORTS.NS")
plt.xlabel("Date")
plt.ylabel("Closing Price (INR)")
plt.show()

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600&family=Crimson+Text:ital,wght@0,400;0,600;1,400&display=swap" rel="stylesheet">
#
# <div style="font-family: 'Inter', -apple-system, sans-serif; color: #1a202c; line-height: 1.6; max-width: 900px; margin: auto; background-color: #ffffff; padding: 25px; border: 1px solid #e2e8f0; border-radius: 8px;">
#
# <div style="text-align: center; padding-bottom: 20px; border-bottom: 2px solid #1a202c; margin-bottom: 30px;">
# <span style="color: #718096; font-size: 12px; text-transform: uppercase; letter-spacing: 2px; font-weight: bold;">
# Quantitative Research Series • Vol. 03
# </span>
#
# <h1 style="font-family: 'Crimson Text', serif; font-style: italic; font-weight: 500; color: #1a202c; font-size: 32px; margin: 10px 0;">
# Module 3 : Statistical and Quantitative Analysis of Stock Market Data
# </h1>
# </div>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 1. Correlation Analysis
# </h3>
#
# <p>
# Correlation analysis examines the statistical relationship between different variables in a dataset.
# For financial market data, this typically includes variables such as:
# </p>
#
# <ul>
# <li>Open price</li>
# <li>High price</li>
# <li>Low price</li>
# <li>Close price</li>
# <li>Trading volume</li>
# </ul>
#
# <p>
# The correlation coefficient ranges between <strong>-1 and 1</strong>.
# </p>
#
# <ul>
# <li><strong>+1</strong> → perfect positive correlation</li>
# <li><strong>0</strong> → no relationship</li>
# <li><strong>-1</strong> → perfect negative correlation</li>
# </ul>
#
# <p>
# In financial datasets, prices such as Open, High, Low, and Close usually exhibit very strong positive correlations because they originate from the same trading process.
# </p>
#
# <p>
# Volume, however, often behaves differently and may show weaker correlations with prices.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 2. Volatility Analysis
# </h3>
#
# <p>
# Volatility represents the degree of variation in an asset’s price over time.
# It is commonly measured using the <strong>standard deviation of returns</strong>.
# </p>
#
# <p style="font-weight:bold;">
# Volatility = Standard Deviation of Returns
# </p>
#
# <p>
# In finance, volatility is a proxy for <strong>risk</strong>.
# </p>
#
# <ul>
# <li>High volatility → large price fluctuations</li>
# <li>Low volatility → stable price movement</li>
# </ul>
#
# <p>
# Many financial models such as the Black–Scholes option pricing model rely heavily on volatility estimation.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 3. Moving Averages
# </h3>
#
# <p>
# Moving averages smooth price data to identify long-term trends.
# Two commonly used moving averages are:
# </p>
#
# <ul>
# <li><strong>50-day moving average</strong></li>
# <li><strong>200-day moving average</strong></li>
# </ul>
#
# <p>
# When the short-term average crosses above the long-term average, it is known as a <strong>Golden Cross</strong>, often interpreted as a bullish signal.
# </p>
#
# <p>
# When the short-term average crosses below the long-term average, it is known as a <strong>Death Cross</strong>, often interpreted as a bearish signal.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 4. Return Analysis
# </h3>
#
# <p>
# Returns measure the percentage change in price between two periods.
# </p>
#
# <p style="font-weight:bold;">
# Return = (P<sub>t</sub> − P<sub>t−1</sub>) / P<sub>t−1</sub>
# </p>
#
# <p>
# Analyzing return distributions helps researchers understand:
# </p>
#
# <ul>
# <li>average profitability</li>
# <li>risk exposure</li>
# <li>extreme market events</li>
# </ul>
#
# <p>
# In quantitative finance, returns are preferred over raw prices because they are scale-independent.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 5. Time Series Analysis
# </h3>
#
# <p>
# Financial data is inherently time-dependent.
# Time series analysis investigates patterns such as:
# </p>
#
# <ul>
# <li>long-term trends</li>
# <li>seasonality</li>
# <li>volatility clustering</li>
# </ul>
#
# <p>
# Models such as ARIMA, VAR, and state-space models are frequently applied to financial time series for forecasting.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 6. Event Analysis
# </h3>
#
# <p>
# Event studies analyze how stock prices respond to significant external events.
# Examples include:
# </p>
#
# <ul>
# <li>earnings announcements</li>
# <li>macroeconomic news</li>
# <li>mergers and acquisitions</li>
# <li>regulatory decisions</li>
# </ul>
#
# <p>
# Event studies help quantify the informational efficiency of financial markets.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 7. Comparative and Benchmark Analysis
# </h3>
#
# <p>
# Stocks are often evaluated relative to market benchmarks such as:
# </p>
#
# <ul>
# <li>S&P 500</li>
# <li>NASDAQ Composite</li>
# <li>sector indices</li>
# </ul>
#
# <p>
# Comparing a stock’s performance with benchmarks helps determine whether it is outperforming or underperforming the broader market.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 8. Risk–Return Metrics
# </h3>
#
# <p>
# Quantitative finance uses several metrics to evaluate the trade-off between risk and return.
# </p>
#
# <ul>
# <li><strong>Sharpe Ratio</strong> – measures excess return per unit of risk</li>
# <li><strong>Sortino Ratio</strong> – penalizes only downside volatility</li>
# <li><strong>Beta</strong> – measures sensitivity to market movements</li>
# </ul>
#
# <p>
# These metrics are widely used in portfolio management and performance evaluation.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 9. Seasonality Analysis
# </h3>
#
# <p>
# Seasonality refers to recurring patterns in asset prices over time.
# Examples include:
# </p>
#
# <ul>
# <li>January effect</li>
# <li>day-of-the-week patterns</li>
# <li>holiday effects</li>
# </ul>
#
# <p>
# Seasonality studies attempt to identify systematic patterns that may offer trading opportunities.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 10. Macroeconomic Correlation
# </h3>
#
# <p>
# Stock prices are influenced by macroeconomic variables such as:
# </p>
#
# <ul>
# <li>interest rates</li>
# <li>inflation</li>
# <li>GDP growth</li>
# <li>unemployment rates</li>
# </ul>
#
# <p>
# Analyzing correlations with macroeconomic indicators helps explain how broader economic forces influence asset prices.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 11. Skewness and Kurtosis Analysis
# </h3>
#
# <p>
# Higher-order moments such as skewness and kurtosis describe the shape of return distributions.
# </p>
#
# <p>
# <strong>Skewness</strong> measures asymmetry.
# </p>
#
# <ul>
# <li>Positive skew → extreme positive returns more likely</li>
# <li>Negative skew → extreme negative returns more likely</li>
# </ul>
#
# <p>
# <strong>Kurtosis</strong> measures tail heaviness.
# </p>
#
# <ul>
# <li>Kurtosis &gt; 3 → heavy tails</li>
# <li>Kurtosis = 3 → normal distribution</li>
# <li>Kurtosis &lt; 3 → light tails</li>
# </ul>
#
# <p>
# Financial return distributions typically exhibit <strong>high kurtosis</strong>, meaning extreme events occur more frequently than predicted by normal distributions.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 12. Advanced Quantitative Methods
# </h3>
#
# <p>
# Modern quantitative research applies advanced statistical and machine learning techniques, including:
# </p>
#
# <ul>
# <li>Monte Carlo simulations</li>
# <li>GARCH volatility models</li>
# <li>cointegration analysis</li>
# <li>Granger causality testing</li>
# <li>machine learning models</li>
# </ul>
#
# <p>
# These techniques help researchers build predictive models, detect trading signals, and manage financial risk.
# </p>
#
#
# <h3 style="color: #2c5282; font-family: 'Crimson Text', serif; font-size: 22px; border-left: 4px solid #2c5282; padding-left: 15px;">
# 13. Risk Management and Portfolio Analysis
# </h3>
#
# <p>
# Risk management tools include:
# </p>
#
# <ul>
# <li>Value at Risk (VaR)</li>
# <li>Expected Shortfall (ES)</li>
# <li>stress testing</li>
# <li>scenario analysis</li>
# </ul>
#
# <p>
# These tools help estimate potential losses under adverse market conditions and guide portfolio construction decisions.
# </p>
#
#
# <p style="margin-top:25px; font-weight:bold;">
# Next Step: Return Transformations, Log Returns, and Volatility Modeling.
# </p>
#
# </div>

# %% [markdown]
# ### NOTE :
#
# Skewness and kurtosis of raw prices usually don't show meaningful information in finance.
#
# Why??
#
# * Stock prices are non-stationary
# * Mean changes over time
# * Variance changes over time
# * Distribution keep shifting
# * price difference solely can not tell us about which asset has moved more

# %%
# kurtois and skewness

def conclusion(df, column_name):
    skewness = df[column_name].skew()
    kurtosis = df[column_name].kurtosis()

    if skewness > 0:
        skewness_conclusion = "The distribution is positively skewed (right-skewed)."
    elif skewness < 0:
        skewness_conclusion = "The distribution is negatively skewed (left-skewed)."
    else:
        skewness_conclusion = "The distribution is symmetric."

    if kurtosis > 3:
        kurtosis_conclusion = "The distribution has heavy tails (leptokurtic)."
    elif kurtosis < 3:
        kurtosis_conclusion = "The distribution has light tails (platykurtic)."
    else:
        kurtosis_conclusion = "The distribution has normal tails (mesokurtic)."

    report = {
        "skewness": skewness,
        "skewness_conclusion": skewness_conclusion,
        "kurtosis": kurtosis,
        "kurtosis_conclusion": kurtosis_conclusion
    }
    
    return report

print(data.columns) # to check the column names and their format
# data is in multiindex format, so we need to use the correct column name to access the "Close" column
# the conclusion function expects a DataFrame and a column name, so we need to pass the DataFrame and the column name as arguments

conclusion_report = conclusion(data, ( 'Close', 'ADANIPORTS.NS'))
print("Skewness:", conclusion_report["skewness"])
print("Skewness Conclusion:", conclusion_report["skewness_conclusion"])
print("Kurtosis:", conclusion_report["kurtosis"])
print("Kurtosis Conclusion:", conclusion_report["kurtosis_conclusion"])
# Out:
# MultiIndex([( 'Close', 'ADANIPORTS.NS'),
#             (  'High', 'ADANIPORTS.NS'),
#             (   'Low', 'ADANIPORTS.NS'),
#             (  'Open', 'ADANIPORTS.NS'),
#             ('Volume', 'ADANIPORTS.NS')],
#            names=['Price', 'Ticker'])
# Skewness: -0.1976018826475462
# Skewness Conclusion: The distribution is negatively skewed (left-skewed).
# Kurtosis: -0.9960029990044665
# Kurtosis Conclusion: The distribution has light tails (platykurtic).

# %%
print(data.index) # to check the index of the DataFrame, which is the date in this case
data.plot(y="Close")

# calculate the average volume traded per day in non-scientific notation
average_volume = data[('Volume', 'ADANIPORTS.NS')].mean() 
print(f"Average Volume Traded per Day: {average_volume:.2f}")
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-05', '2026-01-06',
#                '2026-01-07', '2026-01-08', '2026-01-09', '2026-01-12',
#                '2026-01-13', '2026-01-14', '2026-01-15', '2026-01-16',
#                '2026-01-19', '2026-01-20', '2026-01-21', '2026-01-22',
#                '2026-01-23', '2026-01-27', '2026-01-28', '2026-01-29',
#                '2026-01-30', '2026-02-02', '2026-02-03', '2026-02-04',
#                '2026-02-05', '2026-02-06', '2026-02-09', '2026-02-10',
#                '2026-02-11', '2026-02-12', '2026-02-13', '2026-02-16',
#                '2026-02-17', '2026-02-18', '2026-02-19', '2026-02-20',
#                '2026-02-23', '2026-02-24', '2026-02-25', '2026-02-26',
#                '2026-02-27', '2026-03-02', '2026-03-04', '2026-03-05',
#                '2026-03-06', '2026-03-09', '2026-03-10', '2026-03-11',
#                '2026-03-12', '2026-03-13'],
#               dtype='datetime64[s]', name='Date', freq=None)
# ...

# %% [markdown]
# Trend :
#
# Direction of price
#
# Examples: upward , downward, sideways
#
# Volatility : Magnitude of fluctuations
#
# Sideways but calm → low volatility
#
# Sideways but jagged → high volatility

# %% [markdown]
# *  The stock first declines from ~1490 to ~1310
# *  Then recovers sharply around early February
# *  Later it moves sideways between 1500–1570
# *  Finally drops again toward the end
#
# So overall:
#
# The price series shows trend shifts and volatility bursts, which are common in financial markets.

# %% [markdown]
# Average Volume = 2,434,614 shares/day
#
# That tells us:
#
# a) The stock is liquid
#
# b) Many trades occur daily
#
# c) Price discovery is relatively efficient
#
# <strong>Low volume stocks behave very differently.</strong>

# %% [markdown]
# Observations from Price Plot
#
#
#
# The price series shows different volatility regimes. The early January period appears relatively stable with smaller price fluctuations. After a sharp upward movement in early February, volatility increases and the price oscillates within a sideways range. Toward the end of the observed period, volatility rises again with larger downward movements. This behavior suggests the presence of volatility clustering, a common phenomenon in financial markets.

# %%
# lets analyze the closing prices of every stock in the list of tickers by visualization and basic statistics
for ticker in tickers:
    data = get_stock_data(ticker, "2026-01-01", pd.Timestamp.now().strftime("%Y-%m-%d"))
    print(f"Data for {ticker}:")
    # distribution of closing prices
    sns.histplot(data[('Close', ticker)], kde=True)
    plt.title(f"Distribution of Closing Prices for {ticker}")
    plt.xlabel("Closing Price (INR)")
    plt.ylabel("Frequency")
    plt.show()
    # using data.plot to visualize the closing prices over time
    data.plot(y=('Close'), title=f"Closing Price of {ticker}")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (INR)")
    plt.show()
    # boxplot of closing prices
    sns.boxplot(x=data[('Close', ticker)])
    plt.title(f"Boxplot of Closing Prices for {ticker}")
    plt.xlabel("Closing Price (INR)")
    plt.show()
    # summary statistics for closing prices
    print(f"Summary Statistics for Closing Prices of {ticker}:")
    print(data[('Close', ticker)].describe())
    # calculate and print the average volume traded per day in non-scientific notation
    average_volume = data[('Volume', ticker)].mean()
    print(f"Average Volume Traded per Day for {ticker}: {average_volume:.2f}")
    print("\n")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data for ADANIPORTS.NS:
# [*********************100%***********************]  1 of 1 completed
# Summary Statistics for Closing Prices of ADANIPORTS.NS:
# count      50.000000
# mean     1471.070002
# std        68.641243
# min      1308.400024
# 25%      1420.175049
# 50%      1471.750000
# 75%      1537.774994
# max      1570.199951
# Name: (Close, ADANIPORTS.NS), dtype: float64
# Average Volume Traded per Day for ADANIPORTS.NS: 2513624.96
#
#
# Data for RELINFRA.NS:
# [*********************100%***********************]  1 of 1 completed
# Summary Statistics for Closing Prices of RELINFRA.NS:
# count     50.000000
# mean     121.772599
# std       25.181260
# min       85.500000
# 25%       97.914997
# 50%      120.545002
# 75%      141.089996
# max      164.539993
# Name: (Close, RELINFRA.NS), dtype: float64
# Average Volume Traded per Day for RELINFRA.NS: 1128068.28
#
#
# Data for MON100.NS:
# ...

# %%
# This cell is for testing the data loading functionality of the DataLoader class in the scripts.data_loader module. It imports the DataLoader class, creates an instance of it with the file format set to "parquet", and then uses it to load ticker data for "ADANIPORTS.NS" with a daily interval. Finally, it displays the first few rows of the loaded data using the display function.
import sys 
import os

project_root = os.path.abspath(os.path.abspath('..'))
sys.path.append(project_root)
from scripts.data_loader import DataLoader
loader = DataLoader(file_format="parquet")
df = loader.load_ticker_data("ADANIPORTS.NS","1d")
display(df.head())
df2 = loader.load_ticker_data("RELIANCE.NS","1d")
display(df2.head())
# Out:
# Price              Open         High          Low        Close   Volume
# Date
# 2025-03-11  1131.793674  1140.352011  1118.956106  1129.504761  2399428
# 2025-03-12  1133.485427  1149.557259  1099.650041  1122.837280  2842848
# 2025-03-13  1129.504802  1133.933208  1109.651440  1113.781250  1358839
# 2025-03-17  1109.402643  1142.989239  1105.819976  1131.644409  1489537
# 2025-03-18  1131.644409  1131.644409  1131.644409  1131.644409        0
# Price              Open         High          Low        Close    Volume
# Date
# 2025-03-11  1235.067248  1244.529457  1224.858023  1242.338257  10089838
# 2025-03-12  1252.995611  1257.975720  1239.051303  1252.049438  11977555
# 2025-03-13  1255.037605  1259.121271  1238.901975  1242.935913   9505270
# 2025-03-17  1237.208674  1252.398009  1228.194627  1233.921753  16640917
# 2025-03-18  1233.921753  1233.921753  1233.921753  1233.921753         0

# %% [markdown]
# ### We will be doing further analysis of returns and other statistical parameters in other notebook .

# %% [markdown]
# ### Conclusion and Observation
#
#
# The dataset consists of daily OHLCV data indexed by trading dates. The price series shows trend changes and volatility bursts typical of financial markets. The average trading volume is approximately 2.4 million shares per day, indicating high liquidity. However, raw prices are not suitable for statistical modeling because they are non-stationary and scale dependent. Therefore financial analysis is typically performed using returns rather than prices.
